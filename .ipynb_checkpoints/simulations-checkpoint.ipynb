# %% [markdown]
# # Capstone Project Sandboo

# %% [markdown]
#  For history: new construction and demolition each year.
#
# Demolition can be random but it should be for buildings who are below the zoning capacity.
#
# How to change zoning?
#
# Renting/owning
# Residence with owned units can only be demolished 1/100 times. (Only for 1 unit residences. Maybe make random?
#
# Rent control
#
# Income increase by inflation
#
# Council approval is random variable (very low for SF— find article to support 10% to 15%ish)
#
# Pie charts or stacked histograms for where people live
#
# Initial Price: function of zoning? Function of district exclusivity?
#
# Demand mechanism: if there was unmet demand for housing at a given price, all housing below that price can go up by up to 20% depending on how much unmet demand there was. Or just random choice up to 20%?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.autonotebook import tqdm

import drawSvg as draw
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-8f5827c98853> in <module>()
#       4 from tqdm.autonotebook import tqdm
#       5
# ----> 6 import drawSvg as draw
#
# ModuleNotFoundError: No module named 'drawSvg'

# %%
class Council(object):
    '''
    Haven't decided yet what zoning attribute should be. For now the zone() method
    does not pull directly from the zoning attribute but rather requires a separate
    zoned_as parameter be passed.
    '''
    def __init__(self, zoning):
        self.zoning = zoning
    def zone(self, land, to_zone_as):
        land.zoned_as.append(to_zone_as)

class District(object):
    def __init__(self):
        self.zoned_as = []
        self.blocks = [[]]
    def update(self):
        #Append last time step's blocks
        self.zoned_as.append(self.zoned_as[-1])
        self.blocks.append([b for b in self.blocks[-1]])        
        
class Block(object):
    def __init__(self, size):
        self.size = size
        self.district = None
        self.zoned_as = []
        #Coords where block is. Just for viz
        self.loc = []
        self.residences = [[]]
    def update(self):
        #Append last time step's residences
        self.zoned_as.append(self.zoned_as[-1])
        self.residences.append([r for r in self.residences[-1]])

class Developer(object):
    def __init__(self):
        self.residences_built = [[]]
        
        #Hard coded for now
        self.MIN_RES_SIZE = 425
    def build_on(self, block):
        #Remaining empty land on this block:
        avail_area = block.size - sum([residence.size for residence in block.residences[-1]])
        #If avail_area not large enough to put up a building
        if  avail_area < self.MIN_RES_SIZE:
            return
        #If avail area exceeds min residence size that this developer can build
        else:
            #Distribution of possible sizes for a new residence
            if avail_area > (block.size / 2):
                #Building cannot be bigger than half the block.
                #(Helps with viz.)
                max_res_size = (block.size / 2)
            else:
                #Otherwise building can be as big as the avail land.
                max_res_size = avail_area
            size_dist = np.arange(self.MIN_RES_SIZE, max_res_size + 1)
            #Initialize new residence object
            #Give residence a random size within the realm of possibility
            size = np.random.choice(size_dist)
            residence = Residence(block, size, block.zoned_as[-1])
            #Add residence to last list of residences built on the block
            block.residences[-1].append(residence)
            #Add residence to last list of residence built by this developer
            self.residences_built[-1].append(residence)
    def evict_all(self, residence):
        [u.occ[-1].move_out() for u in residence.units[-1] if u.occ[-1]]
    def demolish(self, residence):
        #Make all households move out
        self.evict_all(residence)
        #Remove this residence from the block's list. (Will remove it from all records moving forward.)
        residence.block.residences[-1].remove(residence)
        #Remove the block from this residence
        residence.block = False

class Residence(object):
    def __init__(self, block, size, zoned_as):
        
        #Building cannot be moved, resized, or rezoned.
        self.block = block
        self.size = size
        self.zoned_as = zoned_as
        #100sqft - about a 9X12 room
        #Hard coded for now
        self.min_unit_size = 100
        
        max_units = self.zoned_as 
        self.units = [[]]
        #Not clear at this point whether nested list will be necessary but am including it for now.
        max_units = zoned_as
        #Units can be larger than 100 sqft
        if size / max_units >= self.min_unit_size:
            self.unit_size = size / max_units
        #But cannot be smaller
        else:
            self.unit_size = self.min_unit_size
        avail_area = self.size
        while  avail_area >= self.unit_size:
            #Create a new unit object
            unit = Unit(self, self.unit_size)
            #Add unit object to last item of Residence's units list.
            self.units[-1].append(unit)
            avail_area -= self.unit_size

class Unit(object):
    def __init__(self, residence, size):
        self.residence = residence
        self.size = size
        #Value is a list. -1 is current value.
        self.value = [(size * price_sqft)]
        #Occupant is a list. -1 is current occupant.
        self.occ = [False]
    def update(self):
        self.value.append(self.value[-1])
        self.occ.append(self.occ[-1])

class Household(object):
    '''
    '''
    def __init__(self, has):
        #List of whether the household is homeless or not
        self.housed = [False]
        #Hold income constant for now but still write as a list
        self.has = [has]
    
    def update(self):
        self.housed.append(self.housed[-1])
        self.has.append(self.has[-1])
    
    def can_move_in(self, unit):
        #household needs a place to live
        #unit not already taken
        # household can afford unit 
        if (not self.housed[-1]) \
        and (not unit.occ[-1]) \
        and (unit.value[-1] <= self.has[-1]):        
            return True
        else: 
            return False
    def must_move_out(self):
        #Household has a place to live
        #buts its value has risen above
        #household's spending power
        #Other conditions can be added later
        if (self.housed[-1]) \
        and self.has[-1] < self.housed[-1].value[-1]:
            return True
        else:
            return False
        
    def move_in(self, unit):
        #Household becomes occupant of unit
        unit.occ[-1] = self
        #Houshold marks itself as housed
        self.housed[-1] = unit
        #print(f'Household {self.has[-1]} now lives in unit {unit.value[-1]}')
    
    def move_out(self):
        #Unit loses occupant
        self.housed[-1].occ[-1] = False
        #Household marks itself as unhoused
        self.housed[-1] = False

def create_councils(self, council_count, zoning):
            #Create a council to zone blocks
    councils = []
    for i in range(council_count):
        council = Council(zoning)
        councils.append(council)
    return councils
        
def create_blocks(self, land, block_size_avg, block_size_std):
    new_blocks = []
    #Create a distribution to simulate variety of block sizes
    #block_dist = np.random.normal(scale = block_size_std, loc = block_size_avg, size = block_count)
    #Create a distribution to simulate variety of zoning
    #Empty for now
    size = BLOCK_SIZE
    while land > 0:
        #size = np.round(np.random.choice(block_dist, replace = False), 0)
        #Create a new block only if the block size will fit on the available land left
        if size > land:
            #Need to break the loop here otherwise it keeps running until a random size is
            #drawn that fits the available remaining land. Could be tiny.
            break
        else:
            #Instantiate a block
            block = Block(size)
            #Reduce available land area by the size of this block
            land -= size
            #Add this block to the list of blocks in the sim
            new_blocks.append(block)
    #Append this list to the list of blocks as the last item        
    return new_blocks

def create_districts(blocks):
    '''
    Map blocks onto districts evenly.
    '''
    blocks_to_assign = [b for b in blocks]
    districts = []
    for i in range(DISTRICTS_COUNT):
        district = District()
        districts.append(district)
    #While there are still blocks to assign
    while blocks_to_assign:
        #For each district
        for d in districts:
            #If the list hasn't run out of values while iterating
            if blocks_to_assign:
                #Give the first block to the district and remove it from the list of blocks
                blocks_to_assign[0].district = d
                d.blocks[-1].append(blocks_to_assign.pop(0))       
            else:
                break
    return districts
    
def create_developers(self, dev_count):
    '''
    Instantiate some number of developer objects.
    '''
    developers = []
    for i in range(dev_count):
        developer = Developer()
        developers.append(developer)
    #Return developers as a list to be stored
    return developers

def round_of_zoning(self, council, districts):
    '''
    Takes one council, not a list of councils.

    '''
    #FOR NOW HARD CODING THE ZONES HERE
    zones = [1, 1, 1, 1, 1, 2, 2, 4, 4, 16]
    
    #Zone each district
    for d, z in zip(districts, zones):
        council.zone(d, z)
        #Zone all the blocks the same way as their district
        for b in d.blocks[-1]:
            council.zone(b, d.zoned_as[-1])
                
def round_of_developing(self, developers, blocks):
    '''
    Iterate over list of developers and call each developer's develop method
    '''
    [developer.build_on(block) for block in blocks for developer in developers]

def create_households(self, pop_growth, has_avg, has_std):
    '''
    Create some number of households to come to the city.
    '''
    income_dist = np.random.normal(scale = has_std, loc = has_avg, size = pop_growth)
    new_households = [Household(i) for i in income_dist]
    #Return the new households as a list
    return new_households

def round_of_moving_in(self):
    '''
    Must be called after time_step() has updated unit and household lists,
    and before round_of_moving_out().
    Prepare lists of units available and unhoused households, then call match()
    to iterate over units to place households in them.
    (What could be a very slow for loop is optimized by preparing shorter lists
    with only the relevant units and households.)
    '''
    print('Round of moving')
    print('#Prepare units and households for moving.')
    #Prepare units and households for moving.
    print('#Step 1: Get units available.')
    #Step 1: Get units available.
    ua = sorted([u for u in self.units[-1] if not u.occ[-1]], \
                        key = lambda u: u.value[-1], reverse = True)
    print(f'{len(ua)} units available')
    print('#Step 2: Get households seeking unit.')
    #Step 2: Get households seeking unit.
    hh = sorted([h for h in self.households[-1] if not h.housed[-1]], \
                        key = lambda h: h.has[-1], reverse = True)
    print(f'{len(hh)} households available')
    print(f'#Step 3: Exclude any units with value above the max spending power of {hh[0].has[-1]}')
    #Step 3: Exclude any units with value above the max spending power 
    #of the households. (Wouldn't be able to rent to anyone)
    ua = [u for u in ua if u.value[-1] <= hh[0].has[-1]]
    #If list is empty, meaning no units are affordable for the richest household
    if not ua:
        print('No units available.')
        return
    print(f'{len(ua)} units available')
    print(f'#Step 4: Exclude any households with spending power less than {ua[0].value[-1]}')
    #Step 4: Exclude any households with spending power less than 
    #the lowest unit value. (Wouldn't be able to find a place.)
    #Keep hh same length as or shorter than ua.
    #(No unit can take more than household so there cannot be more hh than ua.)
    hh = [h for i, h in enumerate(hh) if (h.has[-1] >= ua[-1].value[-1]) and \
                                                                    (i < len(ua))]
    #If list is empty, mmeaning no households can afford what's available
    #This should never happen under the above conditional, but leaving it in for now
    if not hh:
        print('No households looking for units.')
        return
    print(f'{len(hh)} households available')
    print('#Step 5: call the match function to move households into units.')
    #Step 5: call the match function to move households into units.
    hh_remaining = match(hh, ua)
    print(f'{len(hh) - len(hh_remaining)} households out of {len(hh)} found housing')
    #These two numbers should be equal
    #hh_moved_count = sum([1 if h.housed[-1] else 0 for h in hh])
    #ua_moved_into_count = sum([1 if u.occ[-1] else 0 for u in ua])

def match(hh_, ua):
    '''
    Helper function for round of moving. Does the work of matching 
    household to unit. Iterates over units, trying to match each 
    to the highest-value household in the list. If there's a match,
    the household gets popped and the loop moves on to next unit.
    If there's not a match, the loop just moves on to the next unit. 
    A household can take a unit that ncosts less than or equal to
    its spending power. Some rich households may wind up getting 
    cheap units. Units may go untaken; households may go unhoused.

    '''
    #New list to avoid popping the original
    hh = [h for h in hh_]
    #For each unit in list 
    for u in ua:
        #If there are no households left in the list, stop iterating
        if not hh:
            break
        else:
            #If highest-value household can take the unit
            if hh[0].can_move_in(u):
                #Household gets unit
                hh[0].move_in(u)
                #Household gets removed from list
                hh.pop(0)
            #Else: no lower-valued households can take this unit. 
            #It goes unoccupied. Move on to the next unit.
            #Simplest fastest way to iterate over all of them!
    return hh

def round_of_moving_out(self):
    '''
    Must be called after round_of_moving_in().
    A given household should only move_in and move_out once per time step.
    '''
    #Iterate over all households. If a household is housed but 
    #can no longer afford its unit, it moves out.
    test = [h.move_out() for h in self.households[-1] if h.housed[-1] and \
                        h.must_move_out()]
    
    #Should be zero if no hh move out
    print(len(test))                
                
def print_stats(self, time_step):
    print(f'Population at time step {time_step}: {len(self.households[-1])}')
    print(f'{len(self.blocks[-1])} blocks on {LAND} sqft of land')
    print(f'{len(self.developers[-1])} developers')
    #Get number of residences. FOr now there's no master list for some reason
    residences_count = len(self.residences[-1])
    units_count = len(self.units[-1])
    print(f'{residences_count} residences and {units_count} units')
    housing = [True if household.housed[-1] else False for household in self.households[-1]]
    housed_count = sum(housing)
    homeless_count = len(housing) - housed_count
    print(f'{housed_count} households have housing and {homeless_count} households are homeless.')
    
class Simulation(object):
    def __init__(self, 
                 #For creating blocks
                 land, block_count, block_size_avg, block_size_std, zoning,
                 #For bringing builders and rulers to the city
                 dev_count, council_count,
                 #For bringing people to the city
                 pop_growth, has_avg, has_std, 
                 #For running the sim over time
                 total_time_steps, inflation):
        #Number of years to run sim
        self.total_time_steps = total_time_steps
        #List of increments by which to increase population
        self.pop_growth = pop_growth
        #Held as constant for now
        self.has_avg = has_avg
        #Held as constant for now
        self.has_std = has_std
        #Held as constant for now
        self.inflation = inflation
        
        #STEP 0:
        #Create councils
        councils = self.create_councils(council_count, zoning)
        self.councils = [councils]
        
        #STEP 1: 
        #Fill up land area with blocks
        #Will return a list of blocks. Becomes sim.blocks[-1]
        blocks = self.create_blocks(land, block_size_avg, block_size_std)
        self.blocks = [blocks]
    
        #Map all blocks onto districts as evenly as possible. 
        #District count is hard coded as a constant
        #This is done randomly, not by a council, as neighborhoods
        #would coalesce organically in real life.
        districts = create_districts(self.blocks[-1])
        self.districts = [districts]
        #Council zones all the districts and blocks
        #For now its the first council in the list of councils
        self.round_of_zoning(councils[0], self.districts[-1])
       
        #STEP 2: Create developers to build residences
        developers = self.create_developers(dev_count)
        #Start a list of lists of developers to keep track
        self.developers = [developers]
        #Have developers build new residences
        self.round_of_developing(self.developers[-1], self.blocks[-1])
        
        #Start a list of lists of residences
        self.residences = [[r for b in self.blocks[-1] for r in b.residences[-1]]]
        #Start a list of lists of units
        self.units = [[u for r in self.residences[-1] for u in r.units[-1]]]
        
        for d in self.districts[-1]:
            total_area = sum([b.size for b in d.blocks[-1]])
            avail_area = sum([b.size - sum([r.size for r in b.residences[-1]]) for b in d.blocks[-1]])
            print(f'{avail_area} remaining to build on out of {total_area} in district zoned as {d.zoned_as[-1]}')
        
        #STEP 3: Create people to come to the city and move in
        
        #Pop the last value of population growth
        new_households = self.create_households(self.pop_growth.pop(), 
                               self.has_avg, 
                               self.has_std)
        #Start a list of lists of households to keep track
        self.households = [new_households]
        #STEP 4: Let each household try to move into a house
        self.round_of_moving_in()
        
        #STEP 5: Print initial statistics
        print('Simulation started.')
        self.print_stats(0)
        
def time_step(self, step):
    
    #Demolish any old residences
    #pass
    #Kill off any old households
    #pass
    print('\n')
    print(f'Updating object records for time step {step}')
    #Update lists of objects:
    print(f'1. Copy master list of blocks from time step {step - 1}')
    self.blocks.append([b for b in self.blocks[-1]])
    print('2. Update each block\'s own records')
    [b.update() for b in self.blocks[-1]]
    print('3. Update each unit\'s own records')
    #Update each existing unit
    [u.update() for u in self.units[-1]]
    #Update each existing household
    print(f'4. Copy list of developers from time step {step - 1}')
    self.developers.append([d for d in self.developers[-1]])
   
    print(f'5. Copy list of households from time step {step - 1}: ({len(self.households[-1])})')
    #Copy list of households from previous time step
    self.households.append([h for h in self.households[-1]])
    print(f'6. Update each household\'s own records')
    [h.update() for h in self.households[-1]]
    
    #Inflation increases values or something
    
    #New developers
    #Leave out for now
    #Will need to extend [-1] spot of developer list with any new developers
    
    #New households move to town
    print(f'7.New households coming to town!')
    new_households = self.create_households(self.pop_growth.pop(), self.has_avg, self.has_std)
    print(f'{len(new_households)} households arrived')
    self.households[-1].extend(new_households)
    #test to make sure lists of households are updating correctly
    #print([len(h_list) for h_list in self.households])
    print('8. Developers are building new residences on vacant land')
    #Build new residences on available land
    self.round_of_developing(self.developers[-1], self.blocks[-1])
    #Manually append the list of all residences
    print('9. Updating master of list of residences to include new construction')
    self.residences.append([r for b in self.blocks[-1] for r in b.residences[-1]])
    print(f'{len(self.residences[-1]) - len(self.residences[-2])} new residences constructed.')
    #Need to manually add units to list for sim
    print('Appending new units to master list.')
    self.units.append([u for r in self.residences[-1] for u in r.units[-1]])
    #Calculate vacant land left
    #CODE HEREEEEE
    print('Land available after latest round of construction:')
    for d in self.districts[-1]:
        total_area = sum([b.size for b in d.blocks[-1]])
        avail_area = sum([b.size - sum([r.size for r in b.residences[-1]]) for b in d.blocks[-1]])
        print(f'{avail_area} remaining to build on out of {total_area} in district zoned as {d.zoned_as[-1]}')
    #Have homeless try to move into new places
    print('people moving in')
    self.round_of_moving_in()
    
    #Have those priced out of their units move out
    #Shoudl always be a different group of people who move in/out within a year
    print('people moving out')
    self.round_of_moving_out()
    
def run(self):
    pass
    for _ in tqdm(range(self.total_time_steps)):
        # Print out the current time step 
        print(f"Time step {_}")
        self.time_step(_)
        self.print_stats(_)
    

        
def draw_residences(drawing, residences, x, y):
    #Hard coded with block 'height' of 5
    residences_sorted = sorted([r for r in residences], key = lambda r: r.size, reverse = True)
    base_y = y
    BLOCK_DEPTH = 5
    max_y = y + BLOCK_DEPTH
    colors = ['dimgray', 'gray', 'darkgray', 'silver', 'lightgray', 'gainsboro', 'whitesmoke', 
          'lightslategray', 'azure', 'oldlace', 'lightcyan', 'palegoldenrod']
    #How many of the 120 points in a 5x24 grid each building gets
    dots = [r.size // 425 for r in residences_sorted]
    #i.e. street frontage in "dots"
    widths = [dot // 5 if (dot // 5) > 0 else 1 for dot in dots]
    #i.e. how far across the depth of the block in "dots".
    #(Most buildings will have a depth of 5, the whole depth of the block.)
    depths = [5 if (dot // 5) > 0 else dot for dot in dots]
    previous_width = 0
    for w, d in zip (widths, depths):
        #If the depth of this building plus the previous would exceed the edge of the block
        if (y + d) > max_y:
            #Go back to y of 0, edge the bottom edge of the block
            y = base_y
            #Start to the right of the previous building, not in front of it
            x += previous_width
        drawing.append(draw.Rectangle(x,y,w,d, fill = np.random.choice(colors)))
        #Width of this building to use next
        previous_width = w
        #Depth of this buidlign to try to put next building in front of
        y += d

def draw_district(drawing, column_max, blocks):
#Test of blocks with buildings together

    block = draw.Lines((0), (0),
                      (0), (0 + 5),
                      (0 + 24), (0 + 5),
                      (0 + 24), (0),
                      fill = 'white',
                      close = True,
                      stroke = 'black',
                      stroke_width = '0.2',
                      id = 'block')
    x = 0
    y = 0
    column = 0
    column_max = column_max
    alley = True
    #Draw first block from which to copy the others
    #Second block will actually get drawn on top of this one
    drawing.append(block)
    #for b in sim.districts[-1][0].blocks[-1]:
    for b in blocks:
        #Reset for new row above previous
        if column > column_max:
            column = 0
            x = 0
            if alley:
                y += 6
                alley = False
            elif not alley:
                y += 7
                alley = True
        drawing.append(draw.Use('block', x, y))
        draw_residences(drawing, b.residences[-1], x, y)
        x += 26
        column += 1

# %%
#Attach all these functions to the Simulation object
Simulation.create_councils = create_councils
Simulation.create_blocks = create_blocks
Simulation.create_developers = create_developers
Simulation.create_households = create_households
Simulation.round_of_zoning = round_of_zoning
Simulation.round_of_developing = round_of_developing        
Simulation.round_of_moving_in = round_of_moving_in
Simulation.round_of_moving_out = round_of_moving_out
Simulation.print_stats = print_stats
Simulation.time_step = time_step
Simulation.run = run

#CITY SETTINGS
#Size of land area in sqft (for now)
LAND = 1000020000 #one trillion sqft in SF #1000000000
block_count = 10
DISTRICTS_COUNT = 10
BLOCK_SIZE = 51000
#Avg and std not used for now
block_size_avg = 10000 #50000
block_size_std = 150
zoning = [1]

#Starting developers
DEV_COUNT = 1
#Starting councils
COUNCIL_COUNT = 1

#Starting population
#pop_growth = [10000, 10000, 10000, 100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000]
pop_growth = [ 10, 10, 10,  10, 10, 10,  10, 10, 10,  10, 10, 
                10, 10, 10,  10, 10, 10,  10, 10, 10,  10, 10, 
                10, 10, 10,  10, 10, 10,  10, 10, 10,  10, 10, 
                10, 10, 10, 100000, 100000, 100000, 100000, 100000, 100000, 100000, 100000]


has_avg = 1500
has_std = 500

#Time and money
price_sqft = 10
inflation = 0.02
years = 40

# %%
# %%time
#CREATE SIM
sim = Simulation(land = LAND, 
                 block_count = block_count, 
                 block_size_avg = block_size_avg, 
                 block_size_std = block_size_std,
                 zoning = zoning,
                 dev_count = DEV_COUNT,
                 council_count = COUNCIL_COUNT,
                 pop_growth = pop_growth, 
                 has_avg = has_avg, 
                 has_std = has_std, 
                 total_time_steps = years,
                 inflation = inflation
                 )
# Out:
# 74544261.0 remaining to build on out of 100011000 in district zoned as 1
# 74241735.0 remaining to build on out of 100011000 in district zoned as 1
# 74242652.0 remaining to build on out of 100011000 in district zoned as 1
# 74926543.0 remaining to build on out of 100011000 in district zoned as 1
# 74649501.0 remaining to build on out of 100011000 in district zoned as 1
# 75007495.0 remaining to build on out of 100011000 in district zoned as 2
# 75023613.0 remaining to build on out of 100011000 in district zoned as 2
# 74442496.0 remaining to build on out of 100011000 in district zoned as 4
# 74318671.0 remaining to build on out of 99960000 in district zoned as 4
# 74452789.0 remaining to build on out of 99960000 in district zoned as 16
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 63970 units available
# #Step 2: Get households seeking unit.
# 100000 households available
# #Step 3: Exclude any units with value above the max spending power of 3686.476230703734
# 7039 units available
# #Step 4: Exclude any households with spending power less than 3685.0
# 7039 households available
# #Step 5: call the match function to move households into units.
# 5484 households out of 7039 found housing
# Simulation started.
# Population at time step 0: 100000
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 19608 residences and 63970 units
# 5484 households have housing and 94516 households are homeless.
# Wall time: 1.66 s

# %% [markdown]
# #  Running a sim

# %%
# %%time
sim.run()
# Out:
# HBox(children=(IntProgress(value=0, max=40), HTML(value='')))
# Time step 0
#
#
# Updating object records for time step 0
# 1. Copy master list of blocks from time step -1
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step -1
# 5. Copy list of households from time step -1: (100000)
# 6. Update each household's own records
# 7.New households coming to town!
# 100000 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 19608 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 48870042.0 remaining to build on out of 100011000 in district zoned as 1
# 48743168.0 remaining to build on out of 100011000 in district zoned as 1
# 48630004.0 remaining to build on out of 100011000 in district zoned as 1
# 49304441.0 remaining to build on out of 100011000 in district zoned as 1
# 48906859.0 remaining to build on out of 100011000 in district zoned as 1
# 48948154.0 remaining to build on out of 100011000 in district zoned as 2
# 49131583.0 remaining to build on out of 100011000 in district zoned as 2
# 48838999.0 remaining to build on out of 100011000 in district zoned as 4
# 49223130.0 remaining to build on out of 99960000 in district zoned as 4
# 49526688.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 122477 units available
# #Step 2: Get households seeking unit.
# 194516 households available
# #Step 3: Exclude any units with value above the max spending power of 3975.6501016108764
# 9973 units available
# #Step 4: Exclude any households with spending power less than 3975.0
# 9973 households available
# #Step 5: call the match function to move households into units.
# 5569 households out of 9973 found housing
# people moving out
# 0
# Population at time step 0: 200000
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 39216 residences and 127961 units
# 11053 households have housing and 188947 households are homeless.
# Time step 1
#
#
# Updating object records for time step 1
# 1. Copy master list of blocks from time step 0
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 0
# 5. Copy list of households from time step 0: (200000)
# 6. Update each household's own records
# 7.New households coming to town!
# 100000 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 19608 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 27871160.0 remaining to build on out of 100011000 in district zoned as 1
# 27715184.0 remaining to build on out of 100011000 in district zoned as 1
# 28026626.0 remaining to build on out of 100011000 in district zoned as 1
# 27761087.0 remaining to build on out of 100011000 in district zoned as 1
# 27411695.0 remaining to build on out of 100011000 in district zoned as 1
# 28360155.0 remaining to build on out of 100011000 in district zoned as 2
# 27936515.0 remaining to build on out of 100011000 in district zoned as 2
# 28249874.0 remaining to build on out of 100011000 in district zoned as 4
# 28307739.0 remaining to build on out of 99960000 in district zoned as 4
# 28813389.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 180633 units available
# #Step 2: Get households seeking unit.
# 288947 households available
# #Step 3: Exclude any units with value above the max spending power of 3609.071522246716
# 12623 units available
# #Step 4: Exclude any households with spending power less than 3602.5
# 12623 households available
# #Step 5: call the match function to move households into units.
# 7814 households out of 12623 found housing
# people moving out
# 0
# Population at time step 1: 300000
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 58824 residences and 191686 units
# 18867 households have housing and 281133 households are homeless.
# Time step 2
#
#
# Updating object records for time step 2
# 1. Copy master list of blocks from time step 1
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 1
# 5. Copy list of households from time step 1: (300000)
# 6. Update each household's own records
# 7.New households coming to town!
# 100000 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 19287 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 14284192.0 remaining to build on out of 100011000 in district zoned as 1
# 14312911.0 remaining to build on out of 100011000 in district zoned as 1
# 14466187.0 remaining to build on out of 100011000 in district zoned as 1
# 14479383.0 remaining to build on out of 100011000 in district zoned as 1
# 13922691.0 remaining to build on out of 100011000 in district zoned as 1
# 14582932.0 remaining to build on out of 100011000 in district zoned as 2
# 14277543.0 remaining to build on out of 100011000 in district zoned as 2
# 14358985.0 remaining to build on out of 100011000 in district zoned as 4
# 14467423.0 remaining to build on out of 99960000 in district zoned as 4
# 15142564.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 233768 units available
# #Step 2: Get households seeking unit.
# 381133 households available
# #Step 3: Exclude any units with value above the max spending power of 3580.060884169987
# 21642 units available
# #Step 4: Exclude any households with spending power less than 3580.0
# 21642 households available
# #Step 5: call the match function to move households into units.
# 13616 households out of 21642 found housing
# people moving out
# 0
# Population at time step 2: 400000
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 78111 residences and 252635 units
# 32483 households have housing and 367517 households are homeless.
# Time step 3
#
#
# Updating object records for time step 3
# 1. Copy master list of blocks from time step 2
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 2
# 5. Copy list of households from time step 2: (400000)
# 6. Update each household's own records
# 7.New households coming to town!
# 100000 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 17602 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 6823276.0 remaining to build on out of 100011000 in district zoned as 1
# 6978607.0 remaining to build on out of 100011000 in district zoned as 1
# 6966872.0 remaining to build on out of 100011000 in district zoned as 1
# 7170159.0 remaining to build on out of 100011000 in district zoned as 1
# 6797768.0 remaining to build on out of 100011000 in district zoned as 1
# 7175464.0 remaining to build on out of 100011000 in district zoned as 2
# 6858681.0 remaining to build on out of 100011000 in district zoned as 2
# 6960128.0 remaining to build on out of 100011000 in district zoned as 4
# 6822092.0 remaining to build on out of 99960000 in district zoned as 4
# 7309038.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 273620 units available
# #Step 2: Get households seeking unit.
# 467517 households available
# #Step 3: Exclude any units with value above the max spending power of 3917.853366473047
# 34957 units available
# #Step 4: Exclude any households with spending power less than 3915.625
# 34957 households available
# #Step 5: call the match function to move households into units.
# 19212 households out of 34957 found housing
# people moving out
# 0
# Population at time step 3: 500000
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 95713 residences and 306103 units
# 51695 households have housing and 448305 households are homeless.
# Time step 4
#
#
# Updating object records for time step 4
# 1. Copy master list of blocks from time step 3
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 3
# 5. Copy list of households from time step 3: (500000)
# 6. Update each household's own records
# 7.New households coming to town!
# 100000 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 14068 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 3071597.0 remaining to build on out of 100011000 in district zoned as 1
# 3345248.0 remaining to build on out of 100011000 in district zoned as 1
# 3294870.0 remaining to build on out of 100011000 in district zoned as 1
# 3308576.0 remaining to build on out of 100011000 in district zoned as 1
# 3090845.0 remaining to build on out of 100011000 in district zoned as 1
# 3466902.0 remaining to build on out of 100011000 in district zoned as 2
# 3198078.0 remaining to build on out of 100011000 in district zoned as 2
# 3127273.0 remaining to build on out of 100011000 in district zoned as 4
# 3185148.0 remaining to build on out of 99960000 in district zoned as 4
# 3334095.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 294702 units available
# #Step 2: Get households seeking unit.
# 548305 households available
# #Step 3: Exclude any units with value above the max spending power of 3499.4715098628403
# 29899 units available
# #Step 4: Exclude any households with spending power less than 3498.75
# 29899 households available
# #Step 5: call the match function to move households into units.
# 18110 households out of 29899 found housing
# people moving out
# 0
# Population at time step 4: 600000
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 109781 residences and 346397 units
# 69805 households have housing and 530195 households are homeless.
# Time step 5
#
#
# Updating object records for time step 5
# 1. Copy master list of blocks from time step 4
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 4
# 5. Copy list of households from time step 4: (600000)
# 6. Update each household's own records
# 7.New households coming to town!
# 100000 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 9548 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 1508704.0 remaining to build on out of 100011000 in district zoned as 1
# 1529663.0 remaining to build on out of 100011000 in district zoned as 1
# 1535613.0 remaining to build on out of 100011000 in district zoned as 1
# 1577049.0 remaining to build on out of 100011000 in district zoned as 1
# 1469641.0 remaining to build on out of 100011000 in district zoned as 1
# 1658727.0 remaining to build on out of 100011000 in district zoned as 2
# 1484761.0 remaining to build on out of 100011000 in district zoned as 2
# 1504759.0 remaining to build on out of 100011000 in district zoned as 4
# 1536064.0 remaining to build on out of 99960000 in district zoned as 4
# 1555542.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 302689 units available
# #Step 2: Get households seeking unit.
# 630195 households available
# #Step 3: Exclude any units with value above the max spending power of 3655.353296193901
# 29827 units available
# #Step 4: Exclude any households with spending power less than 3655.0
# 29827 households available
# #Step 5: call the match function to move households into units.
# 13940 households out of 29827 found housing
# people moving out
# 0
# Population at time step 5: 700000
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 119329 residences and 372494 units
# 83745 households have housing and 616255 households are homeless.
# Time step 6
#
#
# Updating object records for time step 6
# 1. Copy master list of blocks from time step 5
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 5
# 5. Copy list of households from time step 5: (700000)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 5414 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 790834.0 remaining to build on out of 100011000 in district zoned as 1
# 727027.0 remaining to build on out of 100011000 in district zoned as 1
# 800574.0 remaining to build on out of 100011000 in district zoned as 1
# 811049.0 remaining to build on out of 100011000 in district zoned as 1
# 740241.0 remaining to build on out of 100011000 in district zoned as 1
# 798979.0 remaining to build on out of 100011000 in district zoned as 2
# 744061.0 remaining to build on out of 100011000 in district zoned as 2
# 744017.0 remaining to build on out of 100011000 in district zoned as 4
# 802382.0 remaining to build on out of 99960000 in district zoned as 4
# 784182.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 302892 units available
# #Step 2: Get households seeking unit.
# 616265 households available
# #Step 3: Exclude any units with value above the max spending power of 2619.9077456432487
# 7636 units available
# #Step 4: Exclude any households with spending power less than 2615.0
# 7636 households available
# #Step 5: call the match function to move households into units.
# 6448 households out of 7636 found housing
# people moving out
# 0
# Population at time step 6: 700010
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 124743 residences and 386637 units
# 90193 households have housing and 609817 households are homeless.
# Time step 7
#
#
# Updating object records for time step 7
# 1. Copy master list of blocks from time step 6
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 6
# 5. Copy list of households from time step 6: (700010)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 2566 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 482376.0 remaining to build on out of 100011000 in district zoned as 1
# 436506.0 remaining to build on out of 100011000 in district zoned as 1
# 473920.0 remaining to build on out of 100011000 in district zoned as 1
# 482352.0 remaining to build on out of 100011000 in district zoned as 1
# 456163.0 remaining to build on out of 100011000 in district zoned as 1
# 487935.0 remaining to build on out of 100011000 in district zoned as 2
# 461186.0 remaining to build on out of 100011000 in district zoned as 2
# 460003.0 remaining to build on out of 100011000 in district zoned as 4
# 475669.0 remaining to build on out of 99960000 in district zoned as 4
# 469346.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 303025 units available
# #Step 2: Get households seeking unit.
# 609827 households available
# #Step 3: Exclude any units with value above the max spending power of 2550.4102053726624
# 4840 units available
# #Step 4: Exclude any households with spending power less than 2550.0
# 4840 households available
# #Step 5: call the match function to move households into units.
# 3125 households out of 4840 found housing
# people moving out
# 0
# Population at time step 7: 700020
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 127309 residences and 393218 units
# 93318 households have housing and 606702 households are homeless.
# Time step 8
#
#
# Updating object records for time step 8
# 1. Copy master list of blocks from time step 7
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 7
# 5. Copy list of households from time step 7: (700020)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 1061 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 376224.0 remaining to build on out of 100011000 in district zoned as 1
# 339185.0 remaining to build on out of 100011000 in district zoned as 1
# 360357.0 remaining to build on out of 100011000 in district zoned as 1
# 367531.0 remaining to build on out of 100011000 in district zoned as 1
# 359692.0 remaining to build on out of 100011000 in district zoned as 1
# 379730.0 remaining to build on out of 100011000 in district zoned as 2
# 367505.0 remaining to build on out of 100011000 in district zoned as 2
# 358965.0 remaining to build on out of 100011000 in district zoned as 4
# 367781.0 remaining to build on out of 99960000 in district zoned as 4
# 361186.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 302557 units available
# #Step 2: Get households seeking unit.
# 606712 households available
# #Step 3: Exclude any units with value above the max spending power of 2150.4895914129434
# 1626 units available
# #Step 4: Exclude any households with spending power less than 2150.0
# 1626 households available
# #Step 5: call the match function to move households into units.
# 1307 households out of 1626 found housing
# people moving out
# 0
# Population at time step 8: 700030
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128370 residences and 395875 units
# 94625 households have housing and 605405 households are homeless.
# Time step 9
#
#
# Updating object records for time step 9
# 1. Copy master list of blocks from time step 8
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 8
# 5. Copy list of households from time step 8: (700030)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 369 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 329974.0 remaining to build on out of 100011000 in district zoned as 1
# 315025.0 remaining to build on out of 100011000 in district zoned as 1
# 324962.0 remaining to build on out of 100011000 in district zoned as 1
# 335840.0 remaining to build on out of 100011000 in district zoned as 1
# 326310.0 remaining to build on out of 100011000 in district zoned as 1
# 333882.0 remaining to build on out of 100011000 in district zoned as 2
# 330441.0 remaining to build on out of 100011000 in district zoned as 2
# 334842.0 remaining to build on out of 100011000 in district zoned as 4
# 326433.0 remaining to build on out of 99960000 in district zoned as 4
# 329019.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 302139 units available
# #Step 2: Get households seeking unit.
# 605415 households available
# #Step 3: Exclude any units with value above the max spending power of 2393.2728891802967
# 1867 units available
# #Step 4: Exclude any households with spending power less than 2392.5
# 1867 households available
# #Step 5: call the match function to move households into units.
# 467 households out of 1867 found housing
# people moving out
# 0
# Population at time step 9: 700040
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128739 residences and 396764 units
# 95092 households have housing and 604948 households are homeless.
# Time step 10
#
#
# Updating object records for time step 10
# 1. Copy master list of blocks from time step 9
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 9
# 5. Copy list of households from time step 9: (700040)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 117 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 320448.0 remaining to build on out of 100011000 in district zoned as 1
# 306475.0 remaining to build on out of 100011000 in district zoned as 1
# 317506.0 remaining to build on out of 100011000 in district zoned as 1
# 324988.0 remaining to build on out of 100011000 in district zoned as 1
# 318724.0 remaining to build on out of 100011000 in district zoned as 1
# 322246.0 remaining to build on out of 100011000 in district zoned as 2
# 321234.0 remaining to build on out of 100011000 in district zoned as 2
# 328320.0 remaining to build on out of 100011000 in district zoned as 4
# 316238.0 remaining to build on out of 99960000 in district zoned as 4
# 318059.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301955 units available
# #Step 2: Get households seeking unit.
# 604958 households available
# #Step 3: Exclude any units with value above the max spending power of 2198.584873636441
# 717 units available
# #Step 4: Exclude any households with spending power less than 2197.5
# 717 households available
# #Step 5: call the match function to move households into units.
# 159 households out of 717 found housing
# people moving out
# 0
# Population at time step 10: 700050
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128856 residences and 397047 units
# 95251 households have housing and 604799 households are homeless.
# Time step 11
#
#
# Updating object records for time step 11
# 1. Copy master list of blocks from time step 10
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 10
# 5. Copy list of households from time step 10: (700050)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 28 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 315541.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322901.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 319602.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 324497.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 315244.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301871 units available
# #Step 2: Get households seeking unit.
# 604809 households available
# #Step 3: Exclude any units with value above the max spending power of 2353.4839457663165
# 1334 units available
# #Step 4: Exclude any households with spending power less than 2350.0
# 1334 households available
# #Step 5: call the match function to move households into units.
# 44 households out of 1334 found housing
# people moving out
# 0
# Population at time step 11: 700060
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128884 residences and 397122 units
# 95295 households have housing and 604765 households are homeless.
# Time step 12
#
#
# Updating object records for time step 12
# 1. Copy master list of blocks from time step 11
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 11
# 5. Copy list of households from time step 11: (700060)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 6 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 312332.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301852 units available
# #Step 2: Get households seeking unit.
# 604775 households available
# #Step 3: Exclude any units with value above the max spending power of 2603.609235173382
# 2174 units available
# #Step 4: Exclude any households with spending power less than 2602.5
# 2174 households available
# #Step 5: call the match function to move households into units.
# 21 households out of 2174 found housing
# people moving out
# 0
# Population at time step 12: 700070
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128890 residences and 397147 units
# 95316 households have housing and 604754 households are homeless.
# Time step 13
#
#
# Updating object records for time step 13
# 1. Copy master list of blocks from time step 12
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 12
# 5. Copy list of households from time step 12: (700070)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 1 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301839 units available
# #Step 2: Get households seeking unit.
# 604764 households available
# #Step 3: Exclude any units with value above the max spending power of 2049.9554669961353
# 8 units available
# #Step 4: Exclude any households with spending power less than 1000
# 8 households available
# #Step 5: call the match function to move households into units.
# 8 households out of 8 found housing
# people moving out
# 0
# Population at time step 13: 700080
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95324 households have housing and 604756 households are homeless.
# Time step 14
#
#
# Updating object records for time step 14
# 1. Copy master list of blocks from time step 13
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 13
# 5. Copy list of households from time step 13: (700080)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301831 units available
# #Step 2: Get households seeking unit.
# 604766 households available
# #Step 3: Exclude any units with value above the max spending power of 2411.8446930252435
# 1497 units available
# #Step 4: Exclude any households with spending power less than 2410.0
# 1 households available
# #Step 5: call the match function to move households into units.
# 1 households out of 1 found housing
# people moving out
# 0
# Population at time step 14: 700090
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95325 households have housing and 604765 households are homeless.
# Time step 15
#
#
# Updating object records for time step 15
# 1. Copy master list of blocks from time step 14
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 14
# 5. Copy list of households from time step 14: (700090)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301830 units available
# #Step 2: Get households seeking unit.
# 604775 households available
# #Step 3: Exclude any units with value above the max spending power of 2049.9253720151464
# No units available.
# people moving out
# 0
# Population at time step 15: 700100
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95325 households have housing and 604775 households are homeless.
# Time step 16
#
#
# Updating object records for time step 16
# 1. Copy master list of blocks from time step 15
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 15
# 5. Copy list of households from time step 15: (700100)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301830 units available
# #Step 2: Get households seeking unit.
# 604785 households available
# #Step 3: Exclude any units with value above the max spending power of 2185.5196579190706
# 504 units available
# #Step 4: Exclude any households with spending power less than 2185.0
# 2 households available
# #Step 5: call the match function to move households into units.
# 2 households out of 2 found housing
# people moving out
# 0
# Population at time step 16: 700110
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95327 households have housing and 604783 households are homeless.
# Time step 17
#
#
# Updating object records for time step 17
# 1. Copy master list of blocks from time step 16
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 16
# 5. Copy list of households from time step 16: (700110)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301828 units available
# #Step 2: Get households seeking unit.
# 604793 households available
# #Step 3: Exclude any units with value above the max spending power of 2668.1896184646002
# 2351 units available
# #Step 4: Exclude any households with spending power less than 2665.0
# 1 households available
# #Step 5: call the match function to move households into units.
# 1 households out of 1 found housing
# people moving out
# 0
# Population at time step 17: 700120
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95328 households have housing and 604792 households are homeless.
# Time step 18
#
#
# Updating object records for time step 18
# 1. Copy master list of blocks from time step 17
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 17
# 5. Copy list of households from time step 17: (700120)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301827 units available
# #Step 2: Get households seeking unit.
# 604802 households available
# #Step 3: Exclude any units with value above the max spending power of 2653.213812157711
# 2295 units available
# #Step 4: Exclude any households with spending power less than 2650.0
# 1 households available
# #Step 5: call the match function to move households into units.
# 1 households out of 1 found housing
# people moving out
# 0
# Population at time step 18: 700130
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95329 households have housing and 604801 households are homeless.
# Time step 19
#
#
# Updating object records for time step 19
# 1. Copy master list of blocks from time step 18
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 18
# 5. Copy list of households from time step 18: (700130)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301826 units available
# #Step 2: Get households seeking unit.
# 604811 households available
# #Step 3: Exclude any units with value above the max spending power of 2051.9405136575892
# No units available.
# people moving out
# 0
# Population at time step 19: 700140
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95329 households have housing and 604811 households are homeless.
# Time step 20
#
#
# Updating object records for time step 20
# 1. Copy master list of blocks from time step 19
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 19
# 5. Copy list of households from time step 19: (700140)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301826 units available
# #Step 2: Get households seeking unit.
# 604821 households available
# #Step 3: Exclude any units with value above the max spending power of 2358.6197583103653
# 1312 units available
# #Step 4: Exclude any households with spending power less than 2357.5
# 2 households available
# #Step 5: call the match function to move households into units.
# 2 households out of 2 found housing
# people moving out
# 0
# Population at time step 20: 700150
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95331 households have housing and 604819 households are homeless.
# Time step 21
#
#
# Updating object records for time step 21
# 1. Copy master list of blocks from time step 20
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 20
# 5. Copy list of households from time step 20: (700150)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301824 units available
# #Step 2: Get households seeking unit.
# 604829 households available
# #Step 3: Exclude any units with value above the max spending power of 2051.9405136575892
# No units available.
# people moving out
# 0
# Population at time step 21: 700160
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95331 households have housing and 604829 households are homeless.
# Time step 22
#
#
# Updating object records for time step 22
# 1. Copy master list of blocks from time step 21
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 21
# 5. Copy list of households from time step 21: (700160)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301824 units available
# #Step 2: Get households seeking unit.
# 604839 households available
# #Step 3: Exclude any units with value above the max spending power of 2357.4593242231467
# 1303 units available
# #Step 4: Exclude any households with spending power less than 2355.0
# 1 households available
# #Step 5: call the match function to move households into units.
# 1 households out of 1 found housing
# people moving out
# 0
# Population at time step 22: 700170
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95332 households have housing and 604838 households are homeless.
# Time step 23
#
#
# Updating object records for time step 23
# 1. Copy master list of blocks from time step 22
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 22
# 5. Copy list of households from time step 22: (700170)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301823 units available
# #Step 2: Get households seeking unit.
# 604848 households available
# #Step 3: Exclude any units with value above the max spending power of 2051.9405136575892
# No units available.
# people moving out
# 0
# Population at time step 23: 700180
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# ...
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95344 households have housing and 604916 households are homeless.
# Time step 32
#
#
# Updating object records for time step 32
# 1. Copy master list of blocks from time step 31
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 31
# 5. Copy list of households from time step 31: (700260)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301811 units available
# #Step 2: Get households seeking unit.
# 604926 households available
# #Step 3: Exclude any units with value above the max spending power of 2586.0351314838704
# 2096 units available
# #Step 4: Exclude any households with spending power less than 2585.0
# 2 households available
# #Step 5: call the match function to move households into units.
# 2 households out of 2 found housing
# people moving out
# 0
# Population at time step 32: 700270
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95346 households have housing and 604924 households are homeless.
# Time step 33
#
#
# Updating object records for time step 33
# 1. Copy master list of blocks from time step 32
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 32
# 5. Copy list of households from time step 32: (700270)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301809 units available
# #Step 2: Get households seeking unit.
# 604934 households available
# #Step 3: Exclude any units with value above the max spending power of 2318.3517231949227
# 1133 units available
# #Step 4: Exclude any households with spending power less than 2317.5
# 3 households available
# #Step 5: call the match function to move households into units.
# 3 households out of 3 found housing
# people moving out
# 0
# Population at time step 33: 700280
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95349 households have housing and 604931 households are homeless.
# Time step 34
#
#
# Updating object records for time step 34
# 1. Copy master list of blocks from time step 33
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 33
# 5. Copy list of households from time step 33: (700280)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301806 units available
# #Step 2: Get households seeking unit.
# 604941 households available
# #Step 3: Exclude any units with value above the max spending power of 2451.2353507010466
# 1650 units available
# #Step 4: Exclude any households with spending power less than 2450.0
# 1 households available
# #Step 5: call the match function to move households into units.
# 1 households out of 1 found housing
# people moving out
# 0
# Population at time step 34: 700290
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95350 households have housing and 604940 households are homeless.
# Time step 35
#
#
# Updating object records for time step 35
# 1. Copy master list of blocks from time step 34
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 34
# 5. Copy list of households from time step 34: (700290)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301805 units available
# #Step 2: Get households seeking unit.
# 604950 households available
# #Step 3: Exclude any units with value above the max spending power of 2146.8998910022005
# 320 units available
# #Step 4: Exclude any households with spending power less than 2145.0
# 1 households available
# #Step 5: call the match function to move households into units.
# 1 households out of 1 found housing
# people moving out
# 0
# Population at time step 35: 700300
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95351 households have housing and 604949 households are homeless.
# Time step 36
#
#
# Updating object records for time step 36
# 1. Copy master list of blocks from time step 35
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 35
# 5. Copy list of households from time step 35: (700300)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301804 units available
# #Step 2: Get households seeking unit.
# 604959 households available
# #Step 3: Exclude any units with value above the max spending power of 2685.193102443006
# 2387 units available
# #Step 4: Exclude any households with spending power less than 2685.0
# 3 households available
# #Step 5: call the match function to move households into units.
# 3 households out of 3 found housing
# people moving out
# 0
# Population at time step 36: 700310
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95354 households have housing and 604956 households are homeless.
# Time step 37
#
#
# Updating object records for time step 37
# 1. Copy master list of blocks from time step 36
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 36
# 5. Copy list of households from time step 36: (700310)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301801 units available
# #Step 2: Get households seeking unit.
# 604966 households available
# #Step 3: Exclude any units with value above the max spending power of 2051.9405136575892
# No units available.
# people moving out
# 0
# Population at time step 37: 700320
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95354 households have housing and 604966 households are homeless.
# Time step 38
#
#
# Updating object records for time step 38
# 1. Copy master list of blocks from time step 37
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 37
# 5. Copy list of households from time step 37: (700320)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301801 units available
# #Step 2: Get households seeking unit.
# 604976 households available
# #Step 3: Exclude any units with value above the max spending power of 2051.9405136575892
# No units available.
# people moving out
# 0
# Population at time step 38: 700330
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95354 households have housing and 604976 households are homeless.
# Time step 39
#
#
# Updating object records for time step 39
# 1. Copy master list of blocks from time step 38
# 2. Update each block's own records
# 3. Update each unit's own records
# 4. Copy list of developers from time step 38
# 5. Copy list of households from time step 38: (700330)
# 6. Update each household's own records
# 7.New households coming to town!
# 10 households arrived
# 8. Developers are building new residences on vacant land
# 9. Updating master of list of residences to include new construction
# 0 new residences constructed.
# Appending new units to master list.
# Land available after latest round of construction:
# 314431.0 remaining to build on out of 100011000 in district zoned as 1
# 305855.0 remaining to build on out of 100011000 in district zoned as 1
# 317024.0 remaining to build on out of 100011000 in district zoned as 1
# 322193.0 remaining to build on out of 100011000 in district zoned as 1
# 318076.0 remaining to build on out of 100011000 in district zoned as 1
# 318582.0 remaining to build on out of 100011000 in district zoned as 2
# 320340.0 remaining to build on out of 100011000 in district zoned as 2
# 323962.0 remaining to build on out of 100011000 in district zoned as 4
# 315214.0 remaining to build on out of 99960000 in district zoned as 4
# 311493.0 remaining to build on out of 99960000 in district zoned as 16
# people moving in
# Round of moving
# #Prepare units and households for moving.
# #Step 1: Get units available.
# 301801 units available
# #Step 2: Get households seeking unit.
# 604986 households available
# #Step 3: Exclude any units with value above the max spending power of 2189.6442945734007
# 497 units available
# #Step 4: Exclude any households with spending power less than 2187.5
# 1 households available
# #Step 5: call the match function to move households into units.
# 1 households out of 1 found housing
# people moving out
# 0
# Population at time step 39: 700340
# 19608 blocks on 1000020000 sqft of land
# 1 developers
# 128891 residences and 397155 units
# 95355 households have housing and 604985 households are homeless.
#
# Wall time: 2min 23s

# %% [markdown]
# # Visualizing a district

# %%
#NOTE FOR LATER: IN ORDER TO DEPICT CHANGE IN CONSTRUCTION OF RESIDENCES OVER TIME,
#NEED TO ADJUST VARIABLES TO ALLOW RESIDENCE LIST FROM SPECIFIC TIEM STEP TO BE CHOSEN
drawing = draw.Drawing(600, 800, origin = (0,0))
draw_district(drawing, 17, sim.districts[-1][0].blocks[0])
drawing.setPixelScale(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-dcb65f3a9e18> in <module>()
#       1 #NOTE FOR LATER: IN ORDER TO DEPICT CHANGE IN CONSTRUCTION OF RESIDENCES OVER TIME,
#       2 #NEED TO ADJUST VARIABLES TO ALLOW RESIDENCE LIST FROM SPECIFIC TIEM STEP TO BE CHOSEN
# ----> 3 drawing = draw.Drawing(600, 800, origin = (0,0))
#       4 draw_district(drawing, 17, sim.districts[-1][0].blocks[0])
#       5 drawing.setPixelScale(2)
#
# NameError: name 'draw' is not defined

# %% [markdown]
# # Visualizing the history

# %%
class History(object):
    def __init__(self, simulation):
        '''
        #More info on 'negative indices':
        #Households have 'has' lists of different lengths depending when they entered the sim.
        #Negative index allows loop to get the relevant value from a has list for each year.
        #.e.g. Year -11, year 0 out of 10, gets the -11th, or the first, value from a has list.
        #Year -1, year 10 out of 10, gets the -1th, or last, value from a has list. &c.
        '''
        self.sim = simulation
        
        #BY YEAR:
        #Negative indices to use for lists through time
        b_range = np.flip(np.negative(np.arange(len(sim.blocks))) - 1)
        #####FOR EACH DISTRICT BY YEAR
        area_avail_by_district = [] 
        r_count_by_district = [] 
        r_size_mean_by_district = [] 
        
        u_count_by_district = [] 
        u_size_mean_by_district = [] 
        
        h_count_by_district = []
        h_has_mean_by_district = []
        
        
        for district in sim.districts[-1]:
            #Get area available by district over time
            area_avail_by_district.append([sum([(b.size - sum([r.size for r in b.residences[i]])) \
                     for b in sim.blocks[i] if b.district == district]) for i in b_range])
            #Number of residences by district over time:
            r_counts = [len([r for b in district.blocks[-1] for r in b.residences[i]]) for i in b_range]
            r_count_by_district.append(r_counts)
            #Average residence size by district over time:
            #Get sum of unit sizes per residence, not size of each residence
            r_size_sums = [sum([sum([u.size for u in r.units[-1]]) for b in district.blocks[-1] for r in b.residences[i]]) for i in b_range]
            r_size_mean_by_district.append([r_sum / r_count for r_sum, r_count in zip(r_size_sums, r_counts)])
            #Number of units by district over time:
            u_counts = [len([u for b in district.blocks[-1] for r in b.residences[i] for u in r.units[-1]]) for i in b_range]
            u_count_by_district.append(u_counts)
            #Average unit size by district over time:
            u_sums = [sum([u.size for b in district.blocks[-1] for r in b.residences[i] for u in r.units[-1]]) for i in b_range]
            u_size_mean_by_district.append([u_sum / u_count for u_sum, u_count in zip(u_sums, u_counts)])
            #Average unit value by district over time:
            #NOT YET
            #Number of households in each district over time
            #(Calculated by number of occupied units since each unit has one household)
            h_counts = [sum([1 for b in district.blocks[-1] for r in b.residences[i] for u in r.units[-1] if u.occ[i]]) for i in b_range]
            h_count_by_district.append(h_counts)
            #Average spending power of households in each district over time
            h_has_sums = [sum([u.occ[i].has[i] for b in district.blocks[-1] for r in b.residences[i] for u in r.units[-1] if u.occ[i]]) for i in b_range]
            h_has_mean_by_district.append([h_sum / h_count if h_count else 0 for h_sum, h_count in zip(h_has_sums, h_counts)])

        #List to populate with dataframes for each district
        self.by_districts = []
        for i, district in enumerate(sim.districts[-1]):
            data = np.array([area_avail_by_district[i],
                         r_count_by_district[i], r_size_mean_by_district[i],
                         u_count_by_district[i], u_size_mean_by_district[i], #u_value_mean,
                         h_count_by_district[i],  h_has_mean_by_district[i]]).T
            columns = ['empty_land',
                        'r_count', 'r_size_mean',
                       'u_count', 'u_size_mean', #'u_value_mean', 
                       'h_count', 'h_income_mean']
            self.by_districts.append(pd.DataFrame(data = data, columns = columns))
            
        
        #####FOR ALL DISTRICTS BY YEAR
        area_avail = sum(arr for arr in np.array(area_avail_by_district))
        
        #Number of residences
        r_count = [len(r_list) for r_list in sim.residences]
        #Average residence size
        #Use sum of unit sizes for each residence, not residence size
        r_size_mean = [(sum([sum([u.size for u in r.units[-1]]) for r in r_list]) / len(r_list)) for r_list in sim.residences]
        
        
        #Number of units
        u_count = [len(u_list) for u_list in sim.units]
        #Average unit size
        u_size_mean = [(sum([u.size for u in u_list]) / len(u_list)) for u_list in sim.units]
        #Negative indices to call on lists of varying lengths
        u_range = np.flip(np.negative(np.arange(len(sim.units))) - 1)
        #u_range does not go into dataframe
        #Average unit value
        u_value_mean = [(sum([u.value[i] for u in sim.units[i]]) / len(sim.units[i])) for i in u_range]
        
        h_count = [len(h_list) for h_list in sim.households]
        #hh_range is negative indices by which to call items from has list in each household.
        
        hh_range = np.flip(np.negative(np.arange(len(sim.households))) - 1)
        #hh_range is not included in the dataframe
        #Only households who were housed at the end of each year
        h_housed = [sum([1 for h in sim.households[i] if h.housed[i]]) for i in hh_range]
        #Only households who were unhoused at the end of each year
        h_unhoused = [sum([1 for h in sim.households[i] if not h.housed[i]]) for i in hh_range]
        #Average income of household by year
        h_has_mean = [sum([h.has[i] for h in sim.households[i]])\
                             / len(sim.households[i]) for i in hh_range]
        #Average time household spent living in sim by year
        #(i.e. average 'age' of household by year)
        h_age_mean = [sum([len(h.has[:i]) for h in sim.households[i]]\
                                ) / len(sim.households[i]) for i in hh_range]
        
        data = np.array([area_avail,
                         r_count, r_size_mean,
                         u_count, u_size_mean, u_value_mean,
                         h_count, h_housed, h_unhoused, h_has_mean, h_age_mean
                        ]).T
        columns = ['empty_land',
                    'r_count', 'r_size_mean',
                   'u_count', 'u_size_mean', 'u_value_mean', 
                   'h_count', 'h_housed', 'h_unhoused', 'h_income_mean', 'h_age_mean']
        
        
        self.all_by_year = pd.DataFrame(data = data, columns = columns).rename_axis('Year')
        
    def get_random_hh(self):
        '''
        Generates statistics for a randomly chosen household.
        '''
        hh = np.random.choice(sim.households[-1])
        hh_range = np.flip(np.negative(np.arange(len(hh.housed))) - 1)
        spending_on_housing = [hh.housed[i].value[i] if hh.housed[i] else 0 for i in hh_range]
        size_of_housing = [u.size if u else 0 for u in hh.housed]
        districts_zoned_as = [u.residence.block.district.zoned_as[-1] if u else 0 for u in hh.housed]
        random_hh = pd.DataFrame(data = np.array([spending_on_housing, size_of_housing, districts_zoned_as]).T,
                               columns = ['spending_on_housing', 'size_of_housing', 'districts_zoned_as'])
        return random_hh

# %%
# %%time
hist = History(sim)
# Out:
# Wall time: 1min 44s

# %% [markdown]
# # Looking at a random household

# %%
random_hh = hist.get_random_hh()
random_hh.head()
# Out:
#    spending_on_housing  size_of_housing  districts_zoned_as
# 0             2606.875         260.6875                16.0
# 1             2606.875         260.6875                16.0
# 2             2606.875         260.6875                16.0
# 3             2606.875         260.6875                16.0
# 4             2606.875         260.6875                16.0

# %%
#Household: housing costs
fig = plt.figure(figsize = (12, 8))
plt.plot(random_hh['spending_on_housing'], label = 'Spending on housing')
plt.plot(random_hh['size_of_housing'], label = 'Size of housing')
plt.xlabel('Years')
plt.legend()
plt.title('Housing situation of random household')
# Out:
# Text(0.5,1,'Housing situation of random household')

# %%
#Household: neighborhoods lived in
fig = plt.figure(figsize = (12, 8))
plt.plot(random_hh['districts_zoned_as'], label = 'Zoning of districts lived in')
plt.xlabel('Years')
plt.legend()
plt.title('Zoning of neighborhoods lived in by random household')
# Out:
# Text(0.5,1,'Zoning of neighborhoods lived in by random household')

# %% [markdown]
# # Looking at districts

# %%
#Districts: available land area
district_labels = [str(d.zoned_as[-1]) for d in sim.districts[-1]]
fig = plt.figure(figsize = (12,8))
for i, label in enumerate(district_labels):
    plt.plot(hist.by_districts[i]['empty_land'], label= 'District zoned as ' + label)
#plt.plot(hist.all_by_year['empty_land'], label = 'Total land area available for building')
plt.xlabel('Year')
plt.legend()
plt.title('Land area available by district')
plt.show()

# %%
#Districts: residence counts
district_labels = [str(d.zoned_as[-1]) for d in sim.districts[-1]]
fig = plt.figure(figsize = (12,8))
for i, label in enumerate(district_labels):
    plt.plot(hist.by_districts[i]['r_count'], label = 'District zoned as ' + label)
plt.xlabel('Year')
plt.legend()
plt.title('Residence count by district')
plt.show()

# %%
#Districts: mean residence size
district_labels = [str(d.zoned_as[-1]) for d in sim.districts[-1]]
fig = plt.figure(figsize = (12,8))
for i, label in enumerate(district_labels):
    plt.plot(hist.by_districts[i]['r_size_mean'], label = 'District zoned as ' + label)
plt.xlabel('Year')
plt.legend()
plt.title('Mean residence size by district')
plt.show()

# %%
#Districts: housing unit counts
district_labels = [str(d.zoned_as[-1]) for d in sim.districts[-1]]
fig = plt.figure(figsize = (12,8))
for i, label in enumerate(district_labels):
    plt.plot(hist.by_districts[i]['u_count'], label = 'District zoned as ' + label)
plt.xlabel('Year')
plt.legend()
plt.title('Housing unit count by district')
plt.show()

# %%
#Districts: mean housing unit size
district_labels = [str(d.zoned_as[-1]) for d in sim.districts[-1]]
fig = plt.figure(figsize = (12,8))
for i, label in enumerate(district_labels):
    plt.plot(hist.by_districts[i]['u_size_mean'], label = 'District zoned as ' + label)
plt.xlabel('Year')
plt.legend()
plt.title('Mean housing unit size by district')
plt.show()

# %%
#Districts: household counts
district_labels = [str(d.zoned_as[-1]) for d in sim.districts[-1]]
fig = plt.figure(figsize = (12,8))
for i, label in enumerate(district_labels):
    plt.plot(hist.by_districts[i]['h_count'], label = 'District zoned as ' + label)
plt.xlabel('Year')
plt.legend()
plt.title('Household count by district')
plt.show()

# %%
#Districts: household spending power
district_labels = [str(d.zoned_as[-1]) for d in sim.districts[-1]]
fig = plt.figure(figsize = (12,8))
for i, label in enumerate(district_labels):
    plt.plot(hist.by_districts[i]['h_income_mean'], label = 'District zoned as ' + label)
plt.xlabel('Year')
plt.legend()
plt.title('Mean household spending power by district')
plt.show()

# %% [markdown]
# # Looking at totals

# %%
#Housing and households by year
fig = plt.figure(figsize = (12, 8))
#plt.plot(hist.all_by_year['empty_land'], label = 'Land free for building')
plt.plot(hist.all_by_year['r_count'], label = 'Number of residences')
plt.plot(hist.all_by_year['u_count'], label = 'Number of units')
plt.plot(hist.all_by_year['h_count'], label = 'Number of households')
plt.plot(hist.all_by_year['h_housed'], label = 'Households, housed')
plt.plot(hist.all_by_year['h_unhoused'], label = 'Households, unhoused')
plt.xlabel('Year')
plt.legend()
plt.title('Totals for all districts')
plt.show()

# %%
#Land area by year
fig = plt.figure(figsize = (12, 8))
plt.plot(hist.all_by_year['empty_land'], label = 'Land free for building')
#plt.plot(hist.all_by_year['r_count'], label = 'Number of residences')

plt.xlabel('Year')
plt.legend()
plt.title('Total land area available for building over time')
plt.show()

# %%
#Look at households in city by year
fig = plt.figure(figsize = (12, 8))
#plt.plot(hist.all_by_year['empty_land'], label = 'Land free for building')
plt.plot(hist.all_by_year['u_value_mean'], '+', label = 'Mean housing unit value')
plt.plot(hist.all_by_year['h_income_mean'], '+', label = 'Mean household spending power')
plt.plot(hist.all_by_year['h_count'], label = 'Number of households')
plt.plot(hist.all_by_year['h_housed'], label = 'Households, housed')
plt.plot(hist.all_by_year['h_unhoused'], label = 'Households, unhoused')

plt.xlabel('Year')
plt.legend()
plt.title('Total housing over time')
plt.show()

# %% [markdown]
# # VARIOUS CHECKS FOR OBJECTS IN SIM

# %%
#Zoning of each district
#[d.zoned_as[-1] for d in sim.districts[-1]]

#How many blocks per district
#[len(d.blocks[-1]) for d in sim.districts[-1]]

#CHECK FOR UNIT COUNTS IN DIFFERENT SIZED RESIDENCES
#how to write nested comp: smallest for biggest in biggest for second biggest in second biggest for third biggest in third biggest
#r_sizes = [r.size for d in sim.districts[-1] for b in d.blocks[-1] for r in b.residences[-1]]
#r_unit_count = [len(r.units[-1]) for d in sim.districts[-1] for b in d.blocks[-1] for r in b.residences[-1]]
#for size, unit_count in zip(r_sizes, r_unit_count):
#    print(size, unit_count)

# %%
#For history object
#Test for lengths of these lists. They should all be equal length.
# print(len(residences_count))
# print(len(residence_size_avg))
# print(len(units_count))
# print(len(unit_size_avg))
# print(len(unit_value_avg))
# print(len(household_count))
# print(len(households_housed))
# print(len(households_unhoused))
# print(len(household_age_avg))
# print(len(household_has_avg))

# %%
#This is the available area on one lot
#(sim.lots[0][0].size - sum([r.size for r in sim.lots[0][0].residences[0]]))

#Available area for all lots in one year
#[(l.size - sum([r.size for r in l.residences[0]])) \
#     for l in sim.lots[0]]

#Total area for one year vs avail area for one year
#total = sum([l.size  for l in sim.lots[0]])
#avail = sum([(l.size - sum([r.size for r in l.residences[0]])) \
     #for l in sim.lots[0]])

# %%
#Check sizes of all lots
#sum([lot.size for lot in sim.lots[-1]])

# %%
#Check size of each residence
#[residence.size for lot in sim.lots[-1] for residence in lot.residences[-1]]

# %%
#Check size of each unit
#unit_sizes = [unit.value for lot in sim.lots[-1] for residence in lot.residences[-1] for unit in residence.units[-1]]

# %%
#Check area of each residence that isn't carved into units
#[(residence.size - sum(unit.size for unit in residence.units[-1])) for lot in sim.lots[-1] for residence in lot.residences[-1]]

# %%
#Check unbuilt land of each lot
#avail_area = [lot.size - sum([residence.size for residence in lot.residences[-1]]) for lot in sim.lots[-1]]
#Avail area on each lot should be less than min_size for building a new residence
#avail_area

# %%
#Check how many residences on each lot
#[len(lot.residences[-1]) for lot in sim.lots[-1]]

# %%
#Check how many units in each residence
#[len(residence.units[-1]) for lot in sim.lots[-1] for residence in lot.residences[-1]]

# %%
#Check a single lot
#vars(sim.lots[-1][0])

# %%
#Check a single residence on a lot
#vars(sim.lots[-1][0].residences[-1][0])

# %%
#Check a single unit in a residence
#vars(sim.lots[-1][0].residences[-1][0].units[-1][0])

# %%
#THIS IS GREAT CODE DON'T DELETE
#Check all unit values
#How to quadruple nest a list comprehension:
#smallest for biggest in biggest for second biggest in second biggest for third biggest in third biggest
unit_values = [unit.value[-1] for lot in sim.lots[-1] for residence in lot.residences[-1] for unit in residence.units[-1]]
#unit_values
#plt.hist(unit_values)

# %%
#Get total number of units in all residences on all lots
len([unit.value[-1] for lot in sim.lots[-1] for residence in lot.residences[-1] for unit in residence.units[-1]])

# %%
#Check incomes for all households
#incomes = [household.has[-1] for household in sim.households[-1]]
#plt.hist(incomes)

# %%
#Check incomes for currently housed households
#incomes_currently_housed = [household.has[-1] for household in sim.households[-1] if household.housed[-1]]
#plt.hist(incomes_currently_housed)

# %%
#Check housing history for all households
#housing_history = [household.housed for household in sim.households[-1]]
#housing_history

# %%
# #Test for instantiation of lots, residences built by developers, units per residence
# for lot in sim.lots[-1]:
#     print('Lot size:', lot.size)
#     print('Number of buildings on lot:', len(lot.residences[-1]))
#     for residence in lot.residences[-1]:
#         print('Building size:', residence.size)
#         print('Building zoned as:', residence.zoned_as)
#         print('Units in building:', len(residence.units[-1]))
#         print('Sqft per unit:', residence.size / len(residence.units[-1]))
#         for unit in residence.units[-1]:
#             print('Unit size:', unit.size)
#             print('Unit initial value:', unit.value[0])
#             print('Unit current value:', unit.value[-1])
#             print('Household size:', unit.occ[-1].size)
#             print('Household spending power:', unit.occ[-1].size)
#     print('\n')
